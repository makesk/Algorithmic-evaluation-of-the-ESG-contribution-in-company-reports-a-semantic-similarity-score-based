# %%
import matplotlib.pyplot as plt
import pickle
import dill

ax = pickle.load(open("sebplot.pickle", "rb"))
ax1 = pickle.load(open("luminorplot.pickle", "rb"))
ax2 = pickle.load(open("lhvplot.pickle", "rb"))
ax3 = pickle.load(open("swedplot.pickle", "rb"))
plt.show()

# %%
import matplotlib.pyplot as plt
ax1
ax1.plot()
# Out:
# []

# %%
fig, [[ax, ax1],[ax2, ax3]]  = plt.subplots(2,2,figsize=(10,4))
